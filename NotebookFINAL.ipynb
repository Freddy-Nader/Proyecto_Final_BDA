# %% [markdown]
# # Proyecto final de Bases de Datos Avanzadas
# ## 30 de abril de 2025
# ### Alfredo Nader, Patricio Fernández, Emilio Cruz
# ---

# %% [markdown]
# #### Creación y estructura de la base de datos y del documento

# %% [markdown]
# Iniciamos un entorno virtual de python y bajamos las dependencias necesarias con pip: instalamos pandas para poder usar los datos y alchemy para poder conectar al sql desde python

# %%
pip install pandas sqlalchemy
# Out:
# Requirement already satisfied: pandas in c:\users\emili\appdata\local\programs\python\python313\lib\site-packages (2.2.3)
# Requirement already satisfied: sqlalchemy in c:\users\emili\appdata\local\programs\python\python313\lib\site-packages (2.0.40)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\emili\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\emili\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\emili\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\emili\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.1)
# Requirement already satisfied: greenlet>=1 in c:\users\emili\appdata\local\programs\python\python313\lib\site-packages (from sqlalchemy) (3.2.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\emili\appdata\local\programs\python\python313\lib\site-packages (from sqlalchemy) (4.13.2)
# Requirement already satisfied: six>=1.5 in c:\users\emili\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# y las agregamos al inicio del archivo de python con pd que nos ayuda a manipular los datos en estructuras de tipo DataFrame

# %%
import json
from pymongo import MongoClient
import datetime
import pandas as pd
from sqlalchemy import create_engine, text

# %% [markdown]
# Cargamos los datos del archivo books.json. Dado que es un archivo JSON donde cada línea es un documento separado, usamos pandas.read_json con lines=True.

# %%
df = pd.read_json('books.json', lines=True)

# %% [markdown]
# Convertimos el DataFrame a una lista de diccionarios, que es un formato ideal para insertar en MongoDB.

# %%
data = df.where(pd.notna(df), None).to_dict('records')

# %% [markdown]
# Conectando a SQL:

# %%
#Conexión con sql
engine = create_engine('mysql+pymysql://root:millo1812/proyecto_final')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 engine = create_engine('mysql+pymysql://root:millo1812/proyecto_final')
#
# File <string>:2, in create_engine(url, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\util\deprecations.py:281, in deprecated_params.<locals>.decorate.<locals>.warned(fn, *args, **kwargs)
#     274     if m in kwargs:
#     275         _warn_with_version(
#     276             messages[m],
#     277             versions[m],
#     278             version_warnings[m],
#     279             stacklevel=3,
#     280         )
# --> 281 return fn(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\engine\create.py:549, in create_engine(url, **kwargs)
#     546 kwargs.pop("empty_in_strategy", None)
#     548 # create url.URL object
# --> 549 u = _url.make_url(url)
#     551 u, plugins, kwargs = u._instantiate_plugins(kwargs)
#     553 entrypoint = u._get_entrypoint()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\engine\url.py:856, in make_url(name_or_url)
#     840 """Given a string, produce a new URL instance.
#     841
#     842 The format of the URL generally follows `RFC-1738
#    (...)    852
#     853 """
#     855 if isinstance(name_or_url, str):
# --> 856     return _parse_url(name_or_url)
#     857 elif not isinstance(name_or_url, URL) and not hasattr(
#     858     name_or_url, "_sqla_is_testing_if_this_is_a_mock_object"
#     859 ):
#     860     raise exc.ArgumentError(
#     861         f"Expected string or URL object, got {name_or_url!r}"
#     862     )
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\engine\url.py:917, in _parse_url(name)
#     914     name = components.pop("name")
#     916     if components["port"]:
# --> 917         components["port"] = int(components["port"])
#     919     return URL.create(name, **components)  # type: ignore
#     921 else:
#
# ValueError: invalid literal for int() with base 10: 'millo1812'

# %% [markdown]
# Creando las tablas usando engine.connect directamente a sql

# %%
with engine.connect() as conn:
    conn.execute(text("""
    DROP TABLE IF EXISTS Estados, Categorias, Autores, Libros;
    """))
    conn.execute(text("""
    CREATE TABLE Libros (
        id VARCHAR(24) PRIMARY KEY,
        titulo TEXT,
        isbn TEXT,
        numero_paginas INT,
        fecha_publicacion TEXT,
        url_miniatura TEXT,
        descripcion_corta TEXT,
        descripcion_larga TEXT
    );
    """))
    conn.execute(text("""
    CREATE TABLE Autores (
        id INT AUTO_INCREMENT PRIMARY KEY,
        libro_id VARCHAR(24),
        autor TEXT,
        FOREIGN KEY (libro_id) REFERENCES Libros(id)
    );
    """))
    conn.execute(text("""
    CREATE TABLE Categorias (
        id INT AUTO_INCREMENT PRIMARY KEY,
        libro_id VARCHAR(24),
        categoria TEXT,
        FOREIGN KEY (libro_id) REFERENCES Libros(id)
    );
    """))
    conn.execute(text("""
    CREATE TABLE Estados (
        id INT AUTO_INCREMENT PRIMARY KEY,
        libro_id VARCHAR(24),
        estado TEXT,
        FOREIGN KEY (libro_id) REFERENCES Libros(id)
    );
    """))

# %% [markdown]
# Insertar valores en la tabla con el mismo metodo

# %%
with engine.begin() as conn:
    for _, row in df.iterrows():
        pub = row.get('publishedDate')
        fecha = pub.get('$date') if isinstance(pub, dict) else pub

        page_count = row.get('pageCount')
        if page_count is not None:
            try:
                page_count = int(page_count)
            except (ValueError, TypeError):
                page_count = None

        conn.execute(text("""
            INSERT INTO Libros (id, titulo, isbn, numero_paginas, fecha_publicacion, 
                              url_miniatura, descripcion_corta, descripcion_larga)
            VALUES (:id, :titulo, :isbn, :numero_paginas, :fecha_publicacion, 
                   :url_miniatura, :descripcion_corta, :descripcion_larga);
        """), {
            'id': str(row['_id']),
            'titulo': row.get('title'),
            'isbn': row.get('isbn'),
            'numero_paginas': page_count,
            'fecha_publicacion': fecha,
            'url_miniatura': row.get('thumbnailUrl'),
            'descripcion_corta': row.get('shortDescription'),
            'descripcion_larga': row.get('longDescription')
        })
        
        for autor in row.get('authors') or []:
            if autor: 
                conn.execute(text("""
                    INSERT INTO Autores (libro_id, autor) VALUES (:libro_id, :autor);
                """), {'libro_id': str(row['_id']), 'autor': autor})

        for cat in row.get('categories') or []:
            if cat:
                conn.execute(text("""
                    INSERT INTO Categorias (libro_id, categoria) VALUES (:libro_id, :categoria);
                """), {'libro_id': str(row['_id']), 'categoria': cat})

        estados = row.get('status')
        if isinstance(estados, str):
            estados = [estados]
        for est in estados or []:
            if est: 
                conn.execute(text("""
                    INSERT INTO Estados (libro_id, estado) VALUES (:libro_id, :estado);
                """), {'libro_id': str(row['_id']), 'estado': est})

# %%
import pandas as pd
from sqlalchemy import create_engine, text
import numpy as np

# Connect to MySQL
engine = create_engine('mysql+pymysql://root:warmachinerox2005@127.0.0.1:3306/proyecto_final')


sql_commands = [
    # 1. Transformación de Categorías
    "ALTER TABLE Categorias RENAME TO Categories_old",
    """CREATE TABLE IF NOT EXISTS Categorias (
        id INTEGER PRIMARY KEY AUTO_INCREMENT,
        nombre TEXT
    )""",
    "INSERT INTO Categorias (nombre) SELECT DISTINCT categoria FROM Categories_old",
    
    # 2. Creación de LibroCategoria
    """CREATE TABLE IF NOT EXISTS LibroCategoria (
        libro_id VARCHAR(24) NOT NULL,
        categoria_id INTEGER NOT NULL,
        PRIMARY KEY (libro_id, categoria_id),
        FOREIGN KEY (libro_id) REFERENCES Libros(id),
        FOREIGN KEY (categoria_id) REFERENCES Categorias(id)
    )""",
    """INSERT INTO LibroCategoria (libro_id, categoria_id)
    SELECT co.libro_id, c.id
    FROM Categories_old co
    JOIN Categorias c ON co.categoria = c.nombre""",
    
    # 3. Normalización de Autores
    """CREATE TABLE IF NOT EXISTS AutoresNormalizados (
        id INT AUTO_INCREMENT PRIMARY KEY,
        nombre VARCHAR(100) NOT NULL UNIQUE
    )""",
    "INSERT IGNORE INTO AutoresNormalizados (nombre) SELECT DISTINCT autor FROM Autores",
    
    # 4. Creación de LibroAutor
    """CREATE TABLE IF NOT EXISTS LibroAutor (
        libro_id VARCHAR(24) NOT NULL,
        autor_id INT NOT NULL,
        PRIMARY KEY (libro_id, autor_id),
        FOREIGN KEY (libro_id) REFERENCES Libros(id),
        FOREIGN KEY (autor_id) REFERENCES Autores(id)
    )""",
    """INSERT INTO LibroAutor (libro_id, autor_id)
    SELECT a.libro_id, an.id
    FROM Autores a
    JOIN AutoresNormalizados an ON a.autor = an.nombre""",
    
    # 5. Renombrar tablas (ejecutar solo si todo lo anterior funciona)
    "RENAME TABLE Autores TO Autores_Backup",
    "ALTER TABLE AutoresNormalizados RENAME TO Autores",
    
    # 6. Eliminar tabla backup 
    "ALTER TABLE LibroAutor DROP FOREIGN KEY LibroAutor_ibfk_2",
    "DROP TABLE Autores_Backup"
]

# Ejecutar cada comando por separado
with engine.connect() as conn:
    for cmd in sql_commands:
        try:
            conn.execute(text(cmd))
            conn.commit()  
        except Exception as e:
            print(f"Error al ejecutar: {cmd[:50]}...")
            print(f"Error detallado: {str(e)}")
            conn.rollback()  # Revertir en caso de error
            break  # Detener la ejecución si hay un error

# %% [markdown]
# Verificar que se haya insertado correctamente, imprimiendo los registros y una muestra de las tablas

# %%
with engine.connect() as conn:
    print("\nCounts in each table:")
    for tabla in ['Libros', 'Autores', 'Categorias', 'Estados']:
        count = conn.execute(text(f"SELECT COUNT(*) FROM {tabla}")).fetchone()[0]
        print(f"{tabla}: {count} registros")

    print("\nFirst 5 books:")
    result = conn.execute(text("SELECT id, titulo, isbn FROM Libros LIMIT 5;"))
    for row in result:
        print(row)
# Out:
# Counts in each table:
# Libros: 431 registros
# Autores: 726 registros
# Categorias: 321 registros
# Estados: 431 registros
#
# First 5 books:
# ('1', 'Unlocking Android', '1933988673')
# ('10', 'OSGi in Depth', '193518217X')
# ('11', 'Flexible Rails', '1933988509')
# ('117', 'Managing Components with Modeler', '1932394524k-e')
# ('118', 'Command-line Processing with CLI', '1932394524l-e')

# %% [markdown]
# #### Consultas

# %% [markdown]
# 1. **Consulta por título:** Buscar libros por su título.

# %%
conn = engine.connect()

try:
    titulo = "Android"
    df_titulo = pd.read_sql_query(
        "SELECT * FROM Libros WHERE titulo LIKE %s", 
        conn, 
        params=(f"%{titulo}%",)
    )
    print(df_titulo)
finally:
    conn.close()
# Out:
#     id                             titulo           isbn  numero_paginas  \
# 0    1                  Unlocking Android     1933988673             416
# 1  165                Android in Practice  9781935182924               0
# 2    2  Android in Action, Second Edition     1935182722             592
# 3  514   Android in Action, Third Edition     1617290505               0
# 4   54                Android in Practice     1935182927             500
# 5  580                   50 Android Hacks     1617290564               0
#
#               fecha_publicacion  \
# 0  2009-04-01T00:00:00.000-0700
# 1                          None
# 2  2011-01-14T00:00:00.000-0800
# 3  2011-11-15T00:00:00.000-0800
# 4  2011-09-30T00:00:00.000-0700
# 5  2013-06-03T00:00:00.000-0700
#
#                                        url_miniatura  \
# 0  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 1  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 2  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 3  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 4  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 5  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
#
#                                    descripcion_corta  \
# 0  Unlocking Android: A Developer's Guide provide...
# 1                                               None
# 2  Android in Action, Second Edition is a compreh...
# 3                                               None
# 4  Android in Practice is treasure trove of Andro...
# 5                                               None
#
#                                    descripcion_larga
# 0  Android is an open source mobile phone platfor...
# 1                                               None
# 2  When it comes to mobile apps, Android can do a...
# 3                                               None
# 4  Android, Google's platform for mobile applicat...
# 5                                               None

# %% [markdown]
# 2. **Consulta por ISBN:** Buscar un libro específico mediante su número ISBN.

# %%
with engine.connect() as conn:
    isbn = "1933988673"
    df_isbn = pd.read_sql_query(
        "SELECT * FROM Libros WHERE isbn = %s",
        conn,
        params=(isbn,)
    )
    print(df_isbn)
# Out:
#   id             titulo        isbn  numero_paginas  \
# 0  1  Unlocking Android  1933988673             416
#
#               fecha_publicacion  \
# 0  2009-04-01T00:00:00.000-0700
#
#                                        url_miniatura  \
# 0  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
#
#                                    descripcion_corta  \
# 0  Unlocking Android: A Developer's Guide provide...
#
#                                    descripcion_larga
# 0  Android is an open source mobile phone platfor...

# %% [markdown]
# 3. **Consulta por autor:** Obtener todos los libros escritos por un autor en particular.

# %%
with engine.connect() as conn:
    autor = "W. Frank Ableson"
    df_autor = pd.read_sql_query(
        """
        SELECT L.* 
        FROM Libros L
        JOIN Autores A ON L.id = A.libro_id
        WHERE A.autor = %s
        """, 
        conn, 
        params=(autor.strip(),)  
    )
    print(df_autor)
# Out:
#     id                             titulo        isbn  numero_paginas  \
# 0    1                  Unlocking Android  1933988673             416
# 1    2  Android in Action, Second Edition  1935182722             592
# 2  514   Android in Action, Third Edition  1617290505               0
#
#               fecha_publicacion  \
# 0  2009-04-01T00:00:00.000-0700
# 1  2011-01-14T00:00:00.000-0800
# 2  2011-11-15T00:00:00.000-0800
#
#                                        url_miniatura  \
# 0  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 1  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 2  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
#
#                                    descripcion_corta  \
# 0  Unlocking Android: A Developer's Guide provide...
# 1  Android in Action, Second Edition is a compreh...
# 2                                               None
#
#                                    descripcion_larga
# 0  Android is an open source mobile phone platfor...
# 1  When it comes to mobile apps, Android can do a...
# 2                                               None

# %% [markdown]
# 4. **Consulta por categoría:** Listar libros que pertenecen a una categoría específica.

# %%
with engine.connect() as conn:
    categoria = "Java"
    df_categoria = pd.read_sql_query(
        """
        SELECT L.* 
        FROM Libros L
        JOIN Categorias C ON L.id = C.libro_id
        WHERE C.categoria = %s
        """, 
        conn, 
        params=(categoria.strip(),)  # strip() para limpiar espacios
    )
    print(df_categoria)
# Out:
#      id                             titulo        isbn  numero_paginas  \
# 0     2  Android in Action, Second Edition  1935182722             592
# 1     9                  Griffon in Action  1935182234             375
# 2    10                      OSGi in Depth  193518217X             325
# 3    21    3D User Interfaces with Java 3D  1884777902             520
# 4    22                Hibernate in Action  193239415X             400
# ..  ...                                ...         ...             ...
# 92  320   Spring in Action, Second Edition  1933988134             768
# 93  321    Spring in Action, Third Edition  1935182358             424
# 94  325                 Spring in Practice  1935182056             600
# 95  327               Java 2 Micro Edition  1930110332             504
# 96  331           Java Servlets by Example  188477766X             550
#
#                fecha_publicacion  \
# 0   2011-01-14T00:00:00.000-0800
# 1   2012-06-04T00:00:00.000-0700
# 2   2011-12-12T00:00:00.000-0800
# 3   2000-08-01T00:00:00.000-0700
# 4   2004-08-01T00:00:00.000-0700
# ..                           ...
# 92  2007-08-01T00:00:00.000-0700
# 93  2011-06-21T00:00:00.000-0700
# 94  2013-05-09T00:00:00.000-0700
# 95  2002-03-01T00:00:00.000-0800
# 96  2002-12-01T00:00:00.000-0800
#
#                                         url_miniatura  \
# 0   https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 1   https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 2   https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 3   https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 4   https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# ..                                                ...
# 92  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 93  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 94  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 95  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 96  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
#
#                                     descripcion_corta  \
# 0   Android in Action, Second Edition is a compreh...
# 1   Griffon in Action is a comprehensive tutorial ...
# 2   Enterprise OSGi shows a Java developer how to ...
# 3                                                None
# 4   "2005 Best Java Book!" -- Java Developer's Jou...
# ..                                                ...
# 92                                               None
# 93  Spring in Action, Third Edition has been compl...
# 94  Spring in Practice diverges from other cookboo...
# 95                                               None
# 96                                               None
#
#                                     descripcion_larga
# 0   When it comes to mobile apps, Android can do a...
# 1   Although several options exist for interface d...
# 2   A good application framework greatly simplifie...
# 3   3D User Interfaces with Java 3D is a practical...
# 4   Hibernate practically exploded on the Java sce...
# ..                                                ...
# 92  Spring is a fresh breeze blowing over the Java...
# 93  A few years back, Spring arrived as is a fresh...
# 94  For enterprise Java developers, Spring Framewo...
# 95  Java2, Micro Edition (J2ME) is a technology de...
# 96  Although CGI scripts provide 80% of today's se...
#
# [97 rows x 8 columns]

# %% [markdown]
# 5. **Consulta por estado:** Filtrar libros según su estado.

# %%
with engine.connect() as conn:
    estado = "PUBLISH"
    df_estado = pd.read_sql_query(
        """
        SELECT DISTINCT L.* 
        FROM Libros L
        JOIN Estados E ON L.id = E.libro_id
        WHERE E.estado = %s
        """,
        conn,
        params=(estado.strip(),)
    )
    print(f"Libros con estado '{estado}': {len(df_estado)} encontrados")
  
    print(df_estado[['id', 'titulo', 'isbn']].to_string(index=False))
# Out:
# Libros con estado 'PUBLISH': 363 encontrados
#  id                                                         titulo          isbn
#   1                                              Unlocking Android    1933988673
#   2                              Android in Action, Second Edition    1935182722
#   3                                       Specification by Example    1617290084
#   4                                               Flex 3 in Action    1933988746
#   5                                               Flex 4 in Action    1935182420
#   6                              Collective Intelligence in Action    1933988312
#   7                                       Zend Framework in Action    1933988320
#   8                                                   Flex on Java    1933988797
#   9                                              Griffon in Action    1935182234
#  10                                                  OSGi in Depth    193518217X
#  11                                                 Flexible Rails    1933988509
#  13                                                  Hello! Flex 4    1933988762
#  14                                                    Coffeehouse    1884777384
#  15                          Team Foundation Server 2008 in Action    1933988592
#  16                     Brownfield Application Development in .NET    1933988711
#  17                                              MongoDB in Action    1935182870
#  18      Distributed Application Development with PowerBuilder 6.0    1884777686
#  19                         Jaguar Development with PowerBuilder 7    1884777864
#  20                                                  Taming Jaguar    1884777686
#  21                                3D User Interfaces with Java 3D    1884777902
#  22                                            Hibernate in Action    193239415X
#  23                          Hibernate in Action (Chinese Edition)          None
#  24                                Java Persistence with Hibernate    1932394885
#  25                                                 JSTL in Action    1930110529
#  26                                               iBATIS in Action    1932394826
#  27                                        Designing Hard Software     133046192
#  28                                     Hibernate Search in Action    1933988649
#  29                                               jQuery in Action    1933988355
#  30                               jQuery in Action, Second Edition    1935182323
#  31              Building Secure and Reliable Network Applications    1884777295
#  32                                                 Ruby for Rails    1932394699
#  33                                      The Well-Grounded Rubyist    1933988657
#  35                                         Website Owner's Manual    1933988452
#  36                                        ASP.NET 4.0 in Practice    1935182463
#  37                                                  Hello! Python    1935182080
#  38                              PFC Programmer's Reference Manual    1884777554
#  39                                          Graphics File Formats     133034054
#  40                             Visual Object Oriented Programming     131723979
#  41                                                iOS in Practice    1617291269
#  42                                               iPhone in Action    193398886X
#  43                                        Silverlight 2 in Action    1933988428
#  45                          The Quick Python Book, Second Edition    193518220X
#  46         Internet and Intranet Applications with PowerBuilder 6    1884777600
#  48                   Practical Methods for Your Year 2000 Problem    188477752X
#  51                                                  Mobile Agents    1884777368
#  52                               Spring Dynamic Modules in Action    1935182307
#  53                       SQL Server 2008 Administration in Action    193398872X
#  54                                            Android in Practice    1935182927
#  55                                           Object Oriented Perl    1884777791
#  56                                                GWT in Practice    1933988290
#  59                                                 Ajax in Action    1932394613
#  60                                               Ajax in Practice    1932394990
#  61                          Prototype and Scriptaculous in Action    1933988037
#  63                                                POJOs in Action    1932394583
#  64                                         Data Munging with Perl    1930110006
#  65                                            Hello! HTML5 & CSS3    1935182897
#  66                                                 Seam in Action    1933988401
#  67                                               Wicket in Action    1932394982
#  68                                                Open Source SOA    1933988541
#  69                                             Struts 2 in Action    193398807X
#  70    Essential Guide to Peoplesoft Development and Customization    1884777929
#  71                                            .NET Multithreading    1930110545
#  72                            SCWCD Exam Study Kit Second Edition    1932394389
#  73                                           Spring Roo in Action    193518296X
#  74                                       SOA Governance in Action    1617290270
#  75                                         RSS and Atom in Action    1932394494
#  76                   LDAP Programming, Management and Integration    1930110405
#  77                                                 Mule in Action    1933988967
#  79                                        Java Foundation Classes    1884777678
# 117                               Managing Components with Modeler 1932394524k-e
# 118                               Command-line Processing with CLI 1932394524l-e
# 119                                  Understanding and Using Chain 1932394524m-e
# 120              Working with the Logging and Discovery Components 1932394524n-e
# 121                                Uploading files with FileUpload 1932394524b-e
# 122                      Handling Protocols with the Net Component 1932394524c-e
# 123                                      XML Parsing with Digester 1932394524d-e
# 124                           JXPath and Betwixt: Working with XML 1932394524e-e
# 125                                 Validating Data with Validator 1932394524f-e
# 126                 Enhancing Java Core Libraries with Collections 1932394524g-e
# 127          Enhancing Java Core Libraries with BeanUtils and Lang 1932394524h-e
# 128                 Pool and DBCP: Creating and Using Object Pools 1932394524i-e
# 129                                 Python and Tkinter Programming    1884777813
# 130                                  Microsoft.NET for Programmers    1930110197
# 131                                               Grails in Action    1933988932
# 132                         Up to Speed with Swing, Second Edition    1884777759
# 133                                                 OSGi in Action    1933988916
# 135                                                  GWT in Action    1933988231
# 136                                          The Quick Python Book    1884777740
# 137                            SharePoint 2010 Site Owner's Manual    1933988754
# 139                                      Java Development with Ant    1930110588
# 140                                               Lucene in Action    1932394281
# 141                               Lucene in Action, Second Edition    1933988177
# 142                           PowerBuilder 6.0 Questions & Answers    1884777708
# 143                                    The Awesome Power of PowerJ    1884777538
# 144                                   The Awesome Power of Power++    1884777546
# 145                                                Azure in Action    193518248X
# 147                                        Metaprogramming in .NET    1617290262
# 148                                    Portlets and Apache Portals          None
# 149                                      Code Generation in Action    1930110979
# 150                                      Illustrated Guide to HTTP     138582262
# 152                                                      Agile ALM    1935182633
# 153                       Java Network Programming, Second Edition    188477749X
# 154                                               Struts in Action    1932394249
# 155                                                Camel in Action    1935182366
# 156                                                    Taming Text    193398838X
# 158                                                JBoss in Action    1933988029
# 159                                              Gnuplot in Action    1933988398
# 160                                   Extending and Embedding Perl    1930110820
# 161                                                iOS 4 in Action    1617290017
# 162                              Elements of Programming with Perl    1884777805
# 163                 Learn Windows PowerShell in a Month of Lunches    1617290211
# 164                                                    R in Action    1935182390
# 167                                                   SOA Security    1932394680
# 168                                              Rails 3 in Action    1935182277
# 169                                 Continuous Integration in .NET    1935182552
# 170                                       Technology Paradise Lost    1932394133
# 172                                                     Kermit 95+    1930110057
# 173                                               Laszlo in Action    1932394834
# 174                                               Groovy in Action    1932394842
# 176                        Object Technology Centers of Excellence     132612313
# 177                                                    Test Driven    1932394850
# 178                                         Effective Unit Testing    1935182579
# 179                                             Making Java Groovy    1935182943
# 180                          The Awesome Power of Direct3D/DirectX    1884777473
# 181                                Practical Software Requirements    1884777597
# 182                                           NHibernate in Action    1932394923
# 183                         Microsoft Reporting Services in Action    1932394222
# 184                                              AspectJ in Action    1930110936
# 185                              AspectJ in Action, Second Edition    1933988053
# 186                                               Hadoop in Action    1935182196
# 187                       SQR in PeopleSoft and Other Applications    1884777775
# 188       SQR in PeopleSoft and Other Applications, Second Edition    1932394001
# 190                                          Tuscany SCA in Action    1933988894
# 192                                     Client/Server Yellow Pages    1884777082
# 193                         Object Oriented Application Frameworks    1884777066
# 194                                             Tapestry in Action    1932394117
# 195                                              WebWork in Action    1932394532
# 196                                              MacRuby in Action    1935182498
# 197                                       Erlang and OTP in Action    1933988789
# 198     SharePoint 2007 Developer's Guide to Business Data Catalog    1933988819
# 199                                                 Doing IT Right     133964256
# 200                                            Adobe AIR in Action    1933988487
# 201                                                  Ant in Action    193239480X
# 202                                              Restlet in Action    193518234X
# 203                                                iText in Action    1932394796
# 204                                iText in Action, Second Edition    1935182617
# 205                                                       Power-3D     138412146
# 206                           SNA and TCP/IP Enterprise Networking     131271687
# 208                                           Subversion in Action    1932394478
# 209                                                   Minimal Perl    1932394508
# 210                              Distributed Programming with Java    1884777651
# 211            Comprehensive Networking Glossary and Acronym Guide    013319955X
# 212                                     JavaServer Faces in Action    1932394125
# 213                                                 LINQ in Action    1933988169
# 214                                                  Internet BBSs     132869985
# 215                              Algorithms of the Intelligent Web    1933988665
# 216                                                JUnit in Action    1930110995
# 217                                                 Tika in Action    1935182854
# 218                                               Ruby in Practice    1933988479
# 219                                             Inside LotusScript    1884777481
# 220                                                   Maximum MIDI    1884777449
# 221                             Planning and Managing ATM Networks     132621894
# 222                     Client/Server Applications on ATM Networks     137353006
# 223                                               JavaFX in Action    1933988991
# 224                                   Entity Framework 4 in Action    1935182188
# 225                                ASP.NET 2.0 Web Parts in Action    193239477X
# 226                                     Sass and Compass in Action    1617290149
# 227                                                   Core OWL 5.0    1884777503
# 228                                               Advanced OWL 5.0    1884777465
# 229                                  Server-Based Java Programming    1884777716
# 230                                      SQL Server MVP Deep Dives    1935182048
# 231                                      SQL Server MVP Deep Dives 9781935182047
# 232                                      SQL Server MVP Deep Dives 9781935182047
# 233                                              PostGIS in Action    1935182269
# 235                                           Programming Mac OS X    1930110855
# 236                                        The Art of Unit Testing    1933988274
# 237                                               Mahout in Action    1935182684
# 238                                          ASP.NET MVC in Action    1933988622
# 239                                        ASP.NET MVC 2 in Action    193518279X
# 240                                        ASP.NET MVC 4 in Action    1617290416
# 241                                                EJB 3 in Action    1933988347
# 242                                EJB 3 in Action, Second Edition    1935182994
# 243                           Explorer's Guide to the Semantic Web    1932394206
# 244                                          Practical LotusScript    1884777767
# 245                                   Domino Development with Java    1930110049
# 246                                   Windows PowerShell in Action    1932394907
# 247                   Windows PowerShell in Action, Second Edition    1935182137
# 248                       Silverlight 4 in Action, Revised Edition    1935182374
# 249                                        Silverlight 5 in Action    1617290319
# 250                                              Hibernate Quickly    1932394419
# 251                                                 Generative Art    1935182625
# 252                                      Windows Phone 7 in Action    1617290092
# 253                                                 Lift in Action    1935182803
# 254                           Web Development with Apache and Perl    1930110065
# 255                              Real-World Functional Programming    1933988924
# 256                                     Machine Learning in Action    1617290181
# 257                                           Dependency Injection    193398855X
# 258                                   Understanding Enterprise SOA    1932394591
# 259                                     Open-Source ESBs in Action    1933988215
# 260                                             Activiti in Action    1617290122
# 261                 DSLs in Boo: Domain-Specific Languages in .NET    1933988606
# 262                                                  JUnit Recipes    1932394230
# 263                                             wxPython in Action    1932394621
# 264                                              Clojure in Action    1935182595
# 265                                                Scala in Action    1935182757
# 266                                           Working with Objects     134529308
# 267                                                  PHP in Action    1932394753
# 269                                Secrets of the JavaScript Ninja    193398869X
# 270                                    Microsoft Office Essentials     132623129
# 271                                                          Swing    1884777848
# 272                                           Swing Second Edition    193011088X
# 273                                The Awesome Power of Java Beans    1884777562
# 274                                     Personal Videoconferencing    013268327X
# 275                                      The Cloud at Your Service    1935182528
# 276                       Implementing Elliptic Curve Cryptography    1884777694
# 277                                                   SOA Patterns    1933988266
# 278                                                   Hello World!    1933988495
# 279                                           SCBCD Exam Study Kit    1932394400
# 280                                             Portlets in Action    1935182544
# 281                                            SWT/JFace in Action    1932394273
# 282                                               OpenCL in Action    1617290173
# 283                                         Multiprotocol over ATM     138892709
# 284                                   Dependency Injection in .NET    1935182501
# 285                                            Java 3D Programming    1930110359
# 286                                              Liferay in Action    193518282X
# 287                                              JSP Tag Libraries    193011009X
# 289                                      Instant Messaging in Java    1930110464
# 290                  Java Applets and Channels Without Programming    1884777392
# 291                                         PowerShell in Practice    1935182005
# 292                                             PowerShell and WMI    1617290114
# 293                                           Making Sense of Java     132632942
# 294                                              C++/CLI in Action    1932394818
# 295                                                    C# in Depth    1933988363
# 296                                    C# in Depth, Second Edition    1935182471
# 297                                         Magical A-Life Avatars    1884777589
# 298                                                 Becoming Agile    1933988258
# 299                                             ActiveMQ in Action    1933988940
# 300                             Implementing PeopleSoft Financials     138411808
# 302                                      SQL Server DMVs in Action    1935182730
# 303                                                 Scala in Depth    1935182706
# 304                                                  JMX in Action    1930110561
# 305                                                   EJB Cookbook    1930110944
# 306                                  GWT in Action, Second Edition    1935182846
# 307                                JUnit in Action, Second Edition    1935182021
# 308                                                    Bitter Java    193011043X
# 309                                                     Bitter EJB    1930110952
# 310                                         Spring Batch in Action    1935182951
# 312                                               JDK 1.4 Tutorial    1930110456
# 313                                      iPhone and iPad in Action    1935182587
# 314                   SQL Server 2005 Reporting Services in Action    1932394761
# 315                                  Ten Years of UserFriendly.Org    1935182129
# 316                                 Graphics Programming with Perl    1930110022
# 317                                             RabbitMQ in Action    1935182978
# 318                                              XDoclet in Action    1932394052
# 319                                               Spring in Action    1932394354
# 320                               Spring in Action, Second Edition    1933988134
# 321                                Spring in Action, Third Edition    1935182358
# 325                                             Spring in Practice    1935182056
# 327                                           Java 2 Micro Edition    1930110332
# 328                            SharePoint 2010 Workflows in Action    1935182714
# 329                            SharePoint 2010 Web Parts in Action    1935182773
# 330                                      C++ Concurrency in Action    1933988770
# 331                                       Java Servlets by Example    188477766X
# 332                                XML Programming with VB and ASP    1884777872
# 334                               Oracle8i Database Administration    1884777783
# 512                                      Enterprise OSGi In Action    1617290130
# 513                               Ext JS in Action, Second Edition    1617290327
# 514                               Android in Action, Third Edition    1617290505
# 515                                              Arduino in Action    1617290246
# 516                                              Node.js in Action    1617290572
# 517                                        Third-Party JavaScript     1617290548
# 519                                           Multimedia Computing    020152029X
# 520                          Web Development with JavaServer Pages    1884777996
# 521                                         Up to Speed with Swing    1884777643
# 522                                 Manager's Guide to Open Source    193239429X
# 523                             Programming Web Services with Java    1930110421
# 525                                    TCP/IP Programming for OS/2     132612496
# 530                           Implementing SAP R/3, Second Edition    013889213X
# 531                                           Implementing SAP R/3    1884777228
# 532                         Using C-Kermit: Communication Software    1884777147
# 533                                           SCWCD Exam Study Kit    1930110596
# 549                                            Unit Testing in C++    1617290386
# 551                                         CoffeeScript in Action    1617290629
# 559                            SQL Server MVP Deep Dives, Volume 2    1617290475
# 560                                                HTML5 in Action    1617290491
# 566                                             Hadoop in Practice    1617290238
# 569                                                HBase in Action    1617290521
# 571                                          Flex Mobile in Action    1617290610
# 577                                      HTML5 for .NET Developers    1617290432
# 580                                               50 Android Hacks    1617290564
# 591                                            PowerShell in Depth    1617290556
# 611                                                    Linked Data    1617290394
# 620                                 Mule in Action, Second Edition    1617290823
# 624                                   Single Page Web Applications    1617290750
# 628                        The Art of Unit Testing, Second Edition    1617290890
# 629                                                  Play for Java    1617290904
# 631                                    Hello World! Second Edition    1617290920
# 632                                                 Dart in Action    1617290866
# 634                                                Redis in Action    1617290858
# 636                                Using the TI-83 Plus/TI-84 Plus    161729084X
# 639                          Programming the TI-83 Plus/TI-84 Plus    1617290777
# 641                                                 Play for Scala    1617290793
# 643                                            SonarQube in Action    1617290955
# 644                     Windows Store App Development: C# and XAML    1617290947
# 645                        Learn Windows IIS in a Month of Lunches    1617290971
# 646                                             Mondrian in Action    161729098X
# 650                                               Extending jQuery    161729103X
# 651                 OCA Java SE 7 Programmer I Certification Guide    1617291048
# 652                                               Kanban in Action    1617291056
# 653                                                 Solr in Action    1617291021
# 655                                          Making Sense of NoSQL    1617291072
# 656                         Jaguar Development with PowerBuilder 7    1884777864
# 659 Learn Windows PowerShell in a Month of Lunches, Second Edition    1617291080
# 662                                                    AOP in .NET    1617291145
# 663              Learn PowerShell Toolmaking in a Month of Lunches    1617291161
# 664                            CMIS and Apache Chemistry in Action    1617291153
# 667                                     Action Guide (aka VB .NET)    1930110324
# 670        Learn Active Directory Management in a Month of Lunches    1617291196
# 672                                              The Mikado Method    1617291218
# 677                                          Fast ASP.NET Websites    1617291250
# 679                                          PowerShell Deep Dives    1617291315
# 680                                               Gradle in Action    1617291307
# 686                                     C# in Depth, Third Edition    161729134X
# 691                             The Joy of Clojure, Second Edition    1617291412
# 692                                                iOS 7 in Action    1617291420
# 696                                             Ember.js in Action    1617291455
# 706                                  Practical Data Science with R    1617291560
# 707                  Secrets of the JavaScript Ninja pBook upgrade          None
# 723                                      Windows Phone 8 in Action    1617291374
# 728                      The Well-Grounded Rubyist, Second Edition    1617291692
# 765          Learn SQL Server Administration in a Month of Lunches    1617292133
# 797                                                   XSLT Quickly    1930110111
# 798                              Windows Forms Programming with C#    1930110286
# 799                                        Windows Forms in Action    1932394656
# 800                                     Event Processing in Action    1935182218
# 801                               The Well-Grounded Java Developer    1617290068
# 802                                       Objective-C Fundamentals    1935182536
# 803                                            ADO.NET Programming    1930110294
# 804                          WPF in Action with Visual Studio 2008    1933988223
# 805                                    Location-Aware Applications    1935182331
# 806          Web Development with JavaServer Pages, Second Edition    193011012X
# 807                                        IntelliJ IDEA in Action    1932394443
# 808                                   Spring Integration in Action    1935182439
# 809                                             The Joy of Clojure    1935182641
# 810                            Dynamic WAP Application Development    1930110081
# 811                                           IronPython in Action    1933988339
# 812                                    Art of Java Web Development    1932394060
# 813                                      Java Reflection in Action    1932394184
# 814                                Programming Windows Server 2003    1930110987
# 815                                                 Struts Recipes    1932394249
# 816                                         Hello! iOS Development    1935182986
# 817                                                 Jess in Action    1930110898
# 818                                              Remote LAN Access     134944518
# 819                                       J2EE and XML Development    1930110308
# 820                                              Eclipse in Action    1930110960
# 821                                         ASP.NET AJAX in Action    1933988142
# 822                                               Ext JS in Action    1935182110
# 823                                         Sencha Touch in Action    1617290378
# 824                                                 DSLs in Action    1935182455
# 825                      Database Programming for Handheld Devices    1884777856
# 826                               Jakarta Commons Online Bookshelf    1932394524
# 827                                       Browsing with HttpClient 1932394524a-e
# 828                                   Codec: Encoders and Decoders 1932394524j-e

# %% [markdown]
# 6. **Número total de libros:** Contar el total de libros almacenados en la colección.

# %%
with engine.connect() as conn:
    df_total = pd.read_sql_query("SELECT COUNT(*) AS total_libros FROM Libros", conn)
    print(df_total)
# Out:
#    total_libros
# 0           431

# %%
import pandas as pd
from sqlalchemy import create_engine


engine = create_engine('mysql+pymysql://root:warmachinerox2005@127.0.0.1:3306/proyecto_final')

with engine.connect() as conn:
    # Consulta 7: Libros después de fecha corte
    fecha_corte = '2010-01-01'
    res7 = pd.read_sql_query(
        "SELECT titulo, fecha_publicacion FROM Libros WHERE fecha_publicacion > %s", 
        conn, 
        params=(fecha_corte,)
    )
    print("\n7. Libros después de", fecha_corte)
    print(res7.to_string(index=False))

    # Consulta 8: Autores con más de N libros
    n_libros = 2
    res8 = pd.read_sql_query(
        """SELECT autor, COUNT(*) as num_libros 
           FROM Autores 
           GROUP BY autor 
           HAVING COUNT(*) > %s""",
        conn,
        params=(n_libros,)
    )
    print("\n8. Autores con más de", n_libros, "libros")
    print(res8.to_string(index=False))

    # Consulta 9: Libros sin descripción corta
    res9 = pd.read_sql_query(
        "SELECT titulo FROM Libros WHERE descripcion_corta IS NULL",
        conn
    )
    print("\n9. Libros sin descripción corta")
    print(res9.to_string(index=False))

    # Consulta 10: Conteo por estado
    res10 = pd.read_sql_query(
        "SELECT estado, COUNT(*) as count FROM Estados GROUP BY estado",
        conn
    )
    print("\n10. Conteo por estado")
    print(res10.to_string(index=False))
# Out:
# 7. Libros después de 2010-01-01
#                                                         titulo            fecha_publicacion
#                                                  OSGi in Depth 2011-12-12T00:00:00.000-0800
#                                                 OSGi in Action 2011-04-06T00:00:00.000-0700
#                            SharePoint 2010 Site Owner's Manual 2012-02-13T00:00:00.000-0800
#                               Lucene in Action, Second Edition 2010-07-09T00:00:00.000-0700
#                                                Azure in Action 2010-10-22T00:00:00.000-0700
#                                        Metaprogramming in .NET 2012-12-31T00:00:00.000-0800
#                                                      Agile ALM 2011-08-20T00:00:00.000-0700
#                                                Camel in Action 2011-01-04T00:00:00.000-0800
#                                                    Taming Text 2012-12-31T00:00:00.000-0800
#                     Brownfield Application Development in .NET 2010-04-16T00:00:00.000-0700
#                                                iOS 4 in Action 2011-06-09T00:00:00.000-0700
#                 Learn Windows PowerShell in a Month of Lunches 2011-04-15T00:00:00.000-0700
#                                                    R in Action 2011-08-15T00:00:00.000-0700
#                                              Rails 3 in Action 2011-09-20T00:00:00.000-0700
#                                 Continuous Integration in .NET 2011-03-14T00:00:00.000-0700
#                                              MongoDB in Action 2011-12-12T00:00:00.000-0800
#                                         Effective Unit Testing 2013-02-04T00:00:00.000-0800
#                                             Making Java Groovy 2013-09-19T00:00:00.000-0700
#                                               Hadoop in Action 2010-12-01T00:00:00.000-0800
#                                          Tuscany SCA in Action 2011-02-12T00:00:00.000-0800
#                                              MacRuby in Action 2012-04-11T00:00:00.000-0700
#                                       Erlang and OTP in Action 2010-11-16T00:00:00.000-0800
#                              Android in Action, Second Edition 2011-01-14T00:00:00.000-0800
#                                              Restlet in Action 2012-09-26T00:00:00.000-0700
#                                iText in Action, Second Edition 2010-11-22T00:00:00.000-0800
#                                                 Tika in Action 2011-12-01T00:00:00.000-0800
#                                   Entity Framework 4 in Action 2011-05-01T00:00:00.000-0700
#                                     Sass and Compass in Action 2013-07-26T00:00:00.000-0700
#                                              PostGIS in Action 2011-04-11T00:00:00.000-0700
#                                               Mahout in Action 2011-10-05T00:00:00.000-0700
#                                        ASP.NET MVC 2 in Action 2010-06-01T00:00:00.000-0700
#                                        ASP.NET MVC 4 in Action 2012-05-25T00:00:00.000-0700
#                                EJB 3 in Action, Second Edition 2014-04-07T00:00:00.000-0700
#                   Windows PowerShell in Action, Second Edition 2011-05-15T00:00:00.000-0700
#                       Silverlight 4 in Action, Revised Edition 2010-10-04T00:00:00.000-0700
#                                        Silverlight 5 in Action 2012-06-01T00:00:00.000-0700
#                                                 Generative Art 2011-06-30T00:00:00.000-0700
#                                      Windows Phone 7 in Action 2012-08-21T00:00:00.000-0700
#                                                 Lift in Action 2011-11-18T00:00:00.000-0800
#                                     Machine Learning in Action 2012-04-04T00:00:00.000-0700
#                                             Activiti in Action 2012-07-12T00:00:00.000-0700
#                 DSLs in Boo: Domain-Specific Languages in .NET 2010-01-01T00:00:00.000-0800
#                                              Clojure in Action 2011-11-15T00:00:00.000-0800
#                                                Scala in Action 2013-04-09T00:00:00.000-0700
#                                Secrets of the JavaScript Ninja 2012-12-27T00:00:00.000-0800
#                                      The Cloud at Your Service 2010-11-22T00:00:00.000-0800
#                                                   SOA Patterns 2012-09-12T00:00:00.000-0700
#                                             Portlets in Action 2011-09-16T00:00:00.000-0700
#                                               OpenCL in Action 2011-11-14T00:00:00.000-0800
#                                   Dependency Injection in .NET 2011-10-03T00:00:00.000-0700
#                                              Liferay in Action 2011-09-20T00:00:00.000-0700
#                                         PowerShell in Practice 2010-06-08T00:00:00.000-0700
#                                             PowerShell and WMI 2012-04-30T00:00:00.000-0700
#                                             ActiveMQ in Action 2011-03-31T00:00:00.000-0700
#                                       Specification by Example 2011-06-03T00:00:00.000-0700
#                               jQuery in Action, Second Edition 2010-06-01T00:00:00.000-0700
#                                      SQL Server DMVs in Action 2011-05-09T00:00:00.000-0700
#                                                 Scala in Depth 2012-05-14T00:00:00.000-0700
#                                  GWT in Action, Second Edition 2013-01-21T00:00:00.000-0800
#                                JUnit in Action, Second Edition 2010-07-01T00:00:00.000-0700
#                                         Spring Batch in Action 2011-10-01T00:00:00.000-0700
#                                      iPhone and iPad in Action 2010-08-01T00:00:00.000-0700
#                                             RabbitMQ in Action 2012-04-20T00:00:00.000-0700
#                                Spring in Action, Third Edition 2011-06-21T00:00:00.000-0700
#                                             Spring in Practice 2013-05-09T00:00:00.000-0700
#                            SharePoint 2010 Workflows in Action 2011-02-07T00:00:00.000-0800
#                            SharePoint 2010 Web Parts in Action 2011-04-24T00:00:00.000-0700
#                                      C++ Concurrency in Action 2012-02-24T00:00:00.000-0800
#                                        ASP.NET 4.0 in Practice 2011-05-15T00:00:00.000-0700
#                                                  Hello! Python 2012-02-13T00:00:00.000-0800
#                                                iOS in Practice 2013-11-01T00:00:00.000-0700
#                          The Quick Python Book, Second Edition 2010-01-01T00:00:00.000-0800
#                                               Flex 4 in Action 2010-11-15T00:00:00.000-0800
#                               Ext JS in Action, Second Edition 2014-02-04T00:00:00.000-0800
#                               Android in Action, Third Edition 2011-11-15T00:00:00.000-0800
#                                              Arduino in Action 2013-05-30T00:00:00.000-0700
#                                              Node.js in Action 2013-10-15T00:00:00.000-0700
#                                        Third-Party JavaScript  2013-03-11T00:00:00.000-0700
#                               Spring Dynamic Modules in Action 2010-09-04T00:00:00.000-0700
#                                            Android in Practice 2011-09-30T00:00:00.000-0700
#                                         CoffeeScript in Action 2014-05-09T00:00:00.000-0700
#                            SQL Server MVP Deep Dives, Volume 2 2011-10-13T00:00:00.000-0700
#                                                HTML5 in Action 2014-02-10T00:00:00.000-0800
#                                             Hadoop in Practice 2012-10-02T00:00:00.000-0700
#                                                HBase in Action 2012-11-02T00:00:00.000-0700
#                                          Flex Mobile in Action 2012-05-30T00:00:00.000-0700
#                                      HTML5 for .NET Developers 2012-11-30T00:00:00.000-0800
#                                               50 Android Hacks 2013-06-03T00:00:00.000-0700
#                                            PowerShell in Depth 2013-02-20T00:00:00.000-0800
#                                                    Linked Data 2013-12-31T00:00:00.000-0800
#                                 Mule in Action, Second Edition 2014-02-20T00:00:00.000-0800
#                                   Single Page Web Applications 2013-09-19T00:00:00.000-0700
#                        The Art of Unit Testing, Second Edition 2013-11-25T00:00:00.000-0800
#                                                  Play for Java 2014-03-14T00:00:00.000-0700
#                                    Hello World! Second Edition 2013-12-12T00:00:00.000-0800
#                                                 Dart in Action 2012-12-31T00:00:00.000-0800
#                                                Redis in Action 2013-06-18T00:00:00.000-0700
#                                Using the TI-83 Plus/TI-84 Plus 2013-08-19T00:00:00.000-0700
#                          Programming the TI-83 Plus/TI-84 Plus 2012-09-14T00:00:00.000-0700
#                                                 Play for Scala 2013-10-03T00:00:00.000-0700
#                                            SonarQube in Action 2013-10-30T00:00:00.000-0700
#                     Windows Store App Development: C# and XAML 2013-06-03T00:00:00.000-0700
#                        Learn Windows IIS in a Month of Lunches 2013-12-31T00:00:00.000-0800
#                                            Hello! HTML5 & CSS3 2012-10-17T00:00:00.000-0700
#                                               Extending jQuery 2013-08-12T00:00:00.000-0700
#                 OCA Java SE 7 Programmer I Certification Guide 2013-04-02T00:00:00.000-0700
#                                               Kanban in Action 2014-03-04T00:00:00.000-0800
#                                                 Solr in Action 2014-03-25T00:00:00.000-0700
#                                          Making Sense of NoSQL 2013-09-03T00:00:00.000-0700
# Learn Windows PowerShell in a Month of Lunches, Second Edition 2012-11-12T00:00:00.000-0800
#                                                    AOP in .NET 2013-06-21T00:00:00.000-0700
#              Learn PowerShell Toolmaking in a Month of Lunches 2012-12-12T00:00:00.000-0800
#                                              The Mikado Method 2014-03-05T00:00:00.000-0800
#                                          Fast ASP.NET Websites 2013-08-29T00:00:00.000-0700
#                                               Gradle in Action 2014-02-18T00:00:00.000-0800
#                                     C# in Depth, Third Edition 2013-09-19T00:00:00.000-0700
#                             The Joy of Clojure, Second Edition 2014-05-29T00:00:00.000-0700
#                                                iOS 7 in Action 2014-04-03T00:00:00.000-0700
#                                             Ember.js in Action 2014-06-10T00:00:00.000-0700
#                                  Practical Data Science with R 2014-04-02T00:00:00.000-0700
#                                      Windows Phone 8 in Action 2013-12-31T00:00:00.000-0800
#                      The Well-Grounded Rubyist, Second Edition 2014-06-24T00:00:00.000-0700
#                                           Spring Roo in Action 2012-04-13T00:00:00.000-0700
#                                       SOA Governance in Action 2012-07-27T00:00:00.000-0700
#          Learn SQL Server Administration in a Month of Lunches 2014-05-02T00:00:00.000-0700
#                                                   Flex on Java 2010-10-15T00:00:00.000-0700
#                                     Event Processing in Action 2010-08-15T00:00:00.000-0700
#                               The Well-Grounded Java Developer 2012-07-10T00:00:00.000-0700
#                                       Objective-C Fundamentals 2011-09-13T00:00:00.000-0700
#                                    Location-Aware Applications 2011-07-28T00:00:00.000-0700
#                                   Spring Integration in Action 2012-09-19T00:00:00.000-0700
#                                             The Joy of Clojure 2011-03-25T00:00:00.000-0700
#                                         Hello! iOS Development 2013-07-28T00:00:00.000-0700
#                                               Ext JS in Action 2010-12-05T00:00:00.000-0800
#                                         Sencha Touch in Action 2013-07-12T00:00:00.000-0700
#                                                 DSLs in Action 2010-12-01T00:00:00.000-0800
#                                              Griffon in Action 2012-06-04T00:00:00.000-0700
#
# 8. Autores con más de 2 libros
#              autor  num_libros
#   W. Frank Ableson           3
#    Charlie Collins           3
#           Robi Sen           3
#    Christian Bauer           5
#         Gavin King           5
#      Bear Bibeault           3
#        Yehuda Katz           5
#     David A. Black           3
#  Christopher Allen           3
# Shannon Appelcline           3
#         Dave Crane           3
#   Matthew Scarpino           3
#       Vikram Goyal          12
#       Erik Hatcher           4
#         Tim Hatton           3
#          Don Jones           6
#          Jon Skeet           5
#      Daniel Minoli           3
#         Ted Neward           3
#      Kalen Delaney           4
#           Greg Low           4
#      Adam Machanic           3
#     Paul S. Randal           3
#  Kimberly L. Tripp           3
#    Jeffrey Palermo           3
#       Jimmy Bogard           3
#   Richard Siddaway           6
#       Gary Gregory           3
#        Craig Walls           4
#      Jeffery Hicks           3
#
# 9. Libros sin descripción corta
#                                                         titulo
#                               Managing Components with Modeler
#                               Command-line Processing with CLI
#                                  Understanding and Using Chain
#              Working with the Logging and Discovery Components
#                                Uploading files with FileUpload
#                      Handling Protocols with the Net Component
#                                      XML Parsing with Digester
#                           JXPath and Betwixt: Working with XML
#                                 Validating Data with Validator
#                 Enhancing Java Core Libraries with Collections
#          Enhancing Java Core Libraries with BeanUtils and Lang
#                 Pool and DBCP: Creating and Using Object Pools
#                                 Python and Tkinter Programming
#                                  Microsoft.NET for Programmers
#                                                  GWT in Action
#                                          The Quick Python Book
#                                               Lucene in Action
#                                        Metaprogramming in .NET
#                          Team Foundation Server 2008 in Action
#                                      Illustrated Guide to HTTP
#                       Java Network Programming, Second Edition
#                                               Struts in Action
#                                                JBoss in Action
#                                              Gnuplot in Action
#                                   Extending and Embedding Perl
#                              Elements of Programming with Perl
#                                            Android in Practice
#                                                   SOA Security
#                                                     Kermit 95+
#                                               Laszlo in Action
#                                               Groovy in Action
#                                                    Test Driven
#                                         Effective Unit Testing
#      Distributed Application Development with PowerBuilder 6.0
#                                Practical Software Requirements
#                                           NHibernate in Action
#                         Microsoft Reporting Services in Action
#                                              AspectJ in Action
#                       SQR in PeopleSoft and Other Applications
#       SQR in PeopleSoft and Other Applications, Second Edition
#                                             Tapestry in Action
#                                              WebWork in Action
#                                              MacRuby in Action
#                                                  Taming Jaguar
#                                            Adobe AIR in Action
#                                                       Power-3D
#                                                   Minimal Perl
#                                3D User Interfaces with Java 3D
#                              Distributed Programming with Java
#                                     JavaServer Faces in Action
#                                                 LINQ in Action
#                              Algorithms of the Intelligent Web
#                                                JUnit in Action
#                                                 Tika in Action
#                                               Ruby in Practice
#                                                   Maximum MIDI
#                                               JavaFX in Action
#                                  Server-Based Java Programming
#                          Hibernate in Action (Chinese Edition)
#                                      SQL Server MVP Deep Dives
#                                        The Art of Unit Testing
#                                               Mahout in Action
#                                                EJB 3 in Action
#                                          Practical LotusScript
#                                   Domino Development with Java
#                                        Silverlight 5 in Action
#                                                 JSTL in Action
#                                                 Generative Art
#                                                 Lift in Action
#                           Web Development with Apache and Perl
#                                     Open-Source ESBs in Action
#                                             Activiti in Action
#                                                  JUnit Recipes
#                                                Scala in Action
#                                                          Swing
#                                           Swing Second Edition
#                                The Awesome Power of Java Beans
#                                      The Cloud at Your Service
#                                           SCBCD Exam Study Kit
#                                               OpenCL in Action
#                                            Java 3D Programming
#                                              Liferay in Action
#                                              JSP Tag Libraries
#                                             PowerShell and WMI
#                                                    C# in Depth
#                                       Specification by Example
#                                                  JMX in Action
#                                  GWT in Action, Second Edition
#                                                    Bitter Java
#                                         Spring Batch in Action
#                                               JDK 1.4 Tutorial
#                   SQL Server 2005 Reporting Services in Action
#                                 Graphics Programming with Perl
#                                             RabbitMQ in Action
#                                              XDoclet in Action
#                               Spring in Action, Second Edition
#                                           Java 2 Micro Edition
#                                       Java Servlets by Example
#                                XML Programming with VB and ASP
#                               Oracle8i Database Administration
#                              PFC Programmer's Reference Manual
#                                          Graphics File Formats
#                                               Flex 3 in Action
#                             Visual Object Oriented Programming
#                                                iOS in Practice
#         Internet and Intranet Applications with PowerBuilder 6
#                                               Flex 4 in Action
#                                      Enterprise OSGi In Action
#                               Ext JS in Action, Second Edition
#                               Android in Action, Third Edition
#                                        Third-Party JavaScript
#                                           Multimedia Computing
#                          Web Development with JavaServer Pages
#                                         Up to Speed with Swing
#                                 Manager's Guide to Open Source
#                             Programming Web Services with Java
#                                    TCP/IP Programming for OS/2
#                       SQL Server 2008 Administration in Action
#                           Implementing SAP R/3, Second Edition
#                                           Implementing SAP R/3
#                         Using C-Kermit: Communication Software
#                                           SCWCD Exam Study Kit
#                                            Unit Testing in C++
#                                           Object Oriented Perl
#                                                       Big Data
#                                         CoffeeScript in Action
#                            SQL Server MVP Deep Dives, Volume 2
#                                                GWT in Practice
#                Java Persistence with Hibernate, Second Edition
#                                             Hadoop in Practice
#                                                HBase in Action
#                                          Flex Mobile in Action
#                                      HTML5 for .NET Developers
#                                               50 Android Hacks
#                                                 Ajax in Action
#                                            PowerShell in Depth
#                                     Augmented Reality Revealed
#                              Collective Intelligence in Action
#                                               Ajax in Practice
#               Building Well-Structured JavaScript Applications
#                          Prototype and Scriptaculous in Action
#                                                    Linked Data
#                                 Mule in Action, Second Edition
#                                   Single Page Web Applications
#                        The Art of Unit Testing, Second Edition
#                                                  Play for Java
#                                    Hello World! Second Edition
#                                                 Dart in Action
#                                                Redis in Action
#                                Using the TI-83 Plus/TI-84 Plus
#                                                Neo4j in Action
#                          Programming the TI-83 Plus/TI-84 Plus
#                                         Data Munging with Perl
#                                Functional Programming in Scala
#                                                 Play for Scala
#                                            Node.js in Practice
#                                            SonarQube in Action
#                     Windows Store App Development: C# and XAML
#                        Learn Windows IIS in a Month of Lunches
#                                             Mondrian in Action
#                                              RabbitMQ in Depth
#                                                 Akka in Action
#                                               Extending jQuery
#                 OCA Java SE 7 Programmer I Certification Guide
#                                               Kanban in Action
#                                                 Solr in Action
#                                          Making Sense of NoSQL
#                         Jaguar Development with PowerBuilder 7
#                               Grails in Action, Second Edition
#                                              Rails 4 in Action
# Learn Windows PowerShell in a Month of Lunches, Second Edition
#                                                    AOP in .NET
#              Learn PowerShell Toolmaking in a Month of Lunches
#                            CMIS and Apache Chemistry in Action
#                                     Action Guide (aka VB .NET)
#                                               Wicket in Action
#        Learn Active Directory Management in a Month of Lunches
#                               Spring in Action, Fourth Edition
#                                              The Mikado Method
#                                             The Responsive Web
#                                          Fast ASP.NET Websites
#                                                  SBT in Action
#                                          PowerShell Deep Dives
#                                                Open Source SOA
#                                               Gradle in Action
#                                             Scalatra in Action
#                                            AngularJS in Action
#                                   Software Development Metrics
#                                                  F# Deep Dives
#                                     C# in Depth, Third Edition
#                              PostGIS in Action, Second Edition
#                                    R in Action, Second Edition
#                                             Struts 2 in Action
#                             The Joy of Clojure, Second Edition
#                                                iOS 7 in Action
#                                            Hello App Inventor!
#                                             Ember.js in Action
#                                                Netty in Action
#                                              RavenDB in Action
#    Essential Guide to Peoplesoft Development and Customization
#                OCP Java SE 7 Programmer II Certification Guide
#                                          Backbone.js in Action
#                              Clojure in Action, Second Edition
#                                  Practical Data Science with R
#                  Secrets of the JavaScript Ninja pBook upgrade
#                                            .NET Multithreading
#                                         ArcGIS Web Development
#                                        Elasticsearch in Action
#                          Learn SCCM 2012 in a Month of Lunches
#                  Programming for Musicians and Digital Artists
#                                                  BDD in Action
#                            SCWCD Exam Study Kit Second Edition
#                                      Windows Phone 8 in Action
#                                       Titanium Alloy in Action
#                                               Giraph in Action
#                      The Well-Grounded Rubyist, Second Edition
#                                                   Go in Action
#                                           Spring Roo in Action
#                       The Programmer's Guide to Apache Thrift
#                                Grokking Functional Programming
#                                                 CORS in Action
#                                       Reactive Design Patterns
#                                       SOA Governance in Action
#                                                  Storm Applied
#                                    Real-World Machine Learning
#                                            jQuery UI in Action
#                                       Web Components in Action
#                                  JavaScript Application Design
#                                                Git in Practice
#                                         RSS and Atom in Action
#                                               Impala in Action
#                                               Java 8 in Action
#                                               Elixir in Action
#                              MongoDB in Action, Second Edition
#            Getting MEAN with Mongo, Express, Angular, and Node
#                   LDAP Programming, Management and Integration
#                                jQuery in Action, Third Edition
#                                                D3.js in Action
#          Learn SQL Server Administration in a Month of Lunches
#                                      Geoprocessing with Python
#                                              Barcodes with iOS
#                                                 Mule in Action
#                                                 Chef in Action
#                             Hadoop in Practice, Second Edition
#                                          Oculus Rift in Action
#                                            OpenStack in Action
#                            PowerShell in Depth, Second Edition
#                            Practical Probabilistic Programming
#                                                Unity in Action
#                                        Java Foundation Classes
#                                           Express.js in Action
#                                Learn Git in a Month of Lunches
#                                             Understanding SPAs
#                                                   XSLT Quickly
#                              Windows Forms Programming with C#
#                                        Windows Forms in Action
#                          WPF in Action with Visual Studio 2008
#                                    Location-Aware Applications
#          Web Development with JavaServer Pages, Second Edition
#                            Dynamic WAP Application Development
#                                           IronPython in Action
#                                    Art of Java Web Development
#                                      Java Reflection in Action
#                                Programming Windows Server 2003
#                                                 Struts Recipes
#                                         Hello! iOS Development
#                                       J2EE and XML Development
#                                         ASP.NET AJAX in Action
#                      Database Programming for Handheld Devices
#                               Jakarta Commons Online Bookshelf
#                                   Codec: Encoders and Decoders
#
# 10. Conteo por estado
#  estado  count
# PUBLISH    363
#    MEAP     68

# %%
#Conexión a MongoDB e Inserción de Datos
#Establecemos la conexión con el servidor de Mongo.

# %%
MONGO_URI = 'mongodb://localhost:27017/' 
DATABASE_NAME = 'proyecto_final'
COLLECTION_NAME = 'books'

try:
    client = MongoClient(MONGO_URI)
    db = client[DATABASE_NAME]
    collection = db[COLLECTION_NAME]
    
    client.admin.command('ping')
    print(f"Conexión a MongoDB exitosa. Usando base de datos '{DATABASE_NAME}'.")

except Exception as e:
    print(f"Error al conectar a MongoDB: {e}")
    client = None

# %%
#Antes de insertar, limpiamos la colección para evitar duplicados si ejecutamos el notebook varias veces. Luego insertamos todos los documentos cargados del JSON.

# %%
if client: 
    try:

        delete_result = collection.delete_many({})
        print(f"Documentos existentes eliminados: {delete_result.deleted_count}")

        if data:
            insert_result = collection.insert_many(data)
            print(f"Documentos insertados: {len(insert_result.inserted_ids)}")
        else:
            print("No hay datos para insertar.")

    except Exception as e:
        print(f"Error durante la inserción de datos: {e}")
else:
    print("No se pudo establecer conexión con MongoDB. Saltando inserción.")

# %%
#Verificación

# %%
if client:
    try:
        count = collection.count_documents({})
        print(f"Total de documentos en la colección '{COLLECTION_NAME}': {count}")
        
        print("\nPrimeros 5 documentos en la colección:")
        # Usamos projection para mostrar solo algunos campos para brevedad
        sample_docs = list(collection.find({}, {'_id': 1, 'title': 1, 'isbn': 1}).limit(5))
        for doc in sample_docs:
            print(doc)
            
    except Exception as e:
        print(f"Error durante la verificación de documentos: {e}")
else:
    print("Conexión a MongoDB no establecida. Saltando verificación.")

# %%
#Consultas en Mongo

# %%
#1. Consulta por título: Buscar libros por su título.

# %%
if client:
    search_title = "Action"
    # Usamos $regex para buscar títulos que contengan la palabra, i para case-insensitive
    query = {"title": {"$regex": search_title, "$options": "i"}}
    
    print(f"Buscando libros con '{{search_title}}' en el título...")
    results = list(collection.find(query, {'_id': 1, 'title': 1, 'authors': 1}).limit(10)) # Limitar resultados para mostrar

    df_results = pd.DataFrame(results)
    print(f"Encontrados {len(results)} resultados (mostrando los primeros 10):")
    display(df_results) # Usar display para mostrar DataFrame en Jupyter

# %%
#2. Consulta por ISBN: Buscar un libro específico mediante su número ISBN.

# %%
if client:
    search_isbn = "1933988673"
    query = {"isbn": search_isbn}
    
    print(f"Buscando libro con ISBN '{search_isbn}'...")
    results = list(collection.find(query, {'_id': 1, 'title': 1, 'isbn': 1}))

    df_results = pd.DataFrame(results)
    print(f"Encontrados {len(results)} resultados:")
    display(df_results)

# %%
#3. Consulta por autor: Obtener todos los libros escritos por un autor en particular.

# %%
if client:
    search_author = "W. Frank Ableson"
    # Buscamos documentos donde el array 'authors' contenga el nombre del autor
    query = {"authors": search_author}
    
    print(f"Buscando libros del autor '{search_author}'...")
    results = list(collection.find(query, {'_id': 1, 'title': 1, 'authors': 1}))

    df_results = pd.DataFrame(results)
    print(f"Encontrados {len(results)} resultados:")
    display(df_results)

# %%
#4. Consulta por categoría: Listar libros que pertenecen a una categoría específica.

# %%
if client:
    search_category = "Java"
    # Buscamos documentos donde el array 'categories' contenga la categoría
    query = {"categories": search_category}
    
    print(f"Buscando libros en la categoría '{search_category}'...")
    results = list(collection.find(query, {'_id': 1, 'title': 1, 'categories': 1}))

    df_results = pd.DataFrame(results)
    print(f"Encontrados {len(results)} resultados:")
    display(df_results)

# %%
#5. Consulta por estado: Filtrar libros según su estado.

# %%
if client:
    search_status = "PUBLISH"
    # Basado en la estructura del JSON de ejemplo, 'status' parece ser un string, no un arreglo
    query = {"status": search_status}
    
    print(f"Buscando libros con estado '{search_status}'...")
    results = list(collection.find(query, {'_id': 1, 'title': 1, 'status': 1}))

    df_results = pd.DataFrame(results)
    print(f"Encontrados {len(results)} resultados:")
    display(df_results)

# %%
#7. Buscar libros publicados después de una fecha específica

# %%
if client:
    # Convertir la fecha a un objeto datetime para la consulta
    search_date = datetime.datetime(2010, 1, 1)
    # Usamos $gte (greater than or equal) para encontrar fechas posteriores o iguales
    # La estructura de fecha en el JSON original es un objeto con '$date'
    query = {"publishedDate": {"$gte": search_date}}
    
    print(f"Buscando libros publicados después de {search_date.date()}...")
    # Limitar resultados para mostrar
    results = list(collection.find(query, {'_id': 1, 'title': 1, 'publishedDate': 1}).limit(10))

    df_results = pd.DataFrame(results)
    print(f"Encontrados {len(results)} resultados (mostrando los primeros 10):")
    display(df_results)

# %%
#8. Encontrar libros con un número de páginas dentro de un rango

# %%
if client:
    min_pages = 400
    max_pages = 600
    # Usamos $gte (greater than or equal) y $lte (less than or equal) para el rango
    query = {"pageCount": {"$gte": min_pages, "$lte": max_pages}}
    
    print(f"Buscando libros con un número de páginas entre {min_pages} y {max_pages}...")
     # Limitar resultados para mostrar
    results = list(collection.find(query, {'_id': 1, 'title': 1, 'pageCount': 1}).limit(10))

    df_results = pd.DataFrame(results)
    print(f"Encontrados {len(results)} resultados (mostrando los primeros 10):")
    display(df_results)

# %%
#9. Listar autores distintos presentes en la base de datos

# %%
if client:
    # Usamos distinct para obtener los valores únicos del campo 'authors'
    # Dado que 'authors' es un array, distinct nos dará cada nombre de autor único en todos los arrays.
    try:
        distinct_authors = collection.distinct("authors")
        
        print(f"Total de autores distintos encontrados: {len(distinct_authors)}")
        print("\nPrimeros 20 autores distintos:")
        # Mostrar solo los primeros 20 para brevedad
        for i, author in enumerate(distinct_authors[:20]):
            print(f"- {author}")
    except Exception as e:
        print(f"Error al obtener autores distintos: {e}")

# %%
#10. Contar libros por estado

# %%
if client:
    # Usamos el framework de agregación para agrupar por estado y contar
    pipeline = [
        {"$group": {"_id": "$status", "count": {"$sum": 1}}}
    ]
    
    print("Contando libros por estado...")
    results = list(collection.aggregate(pipeline))

    df_results = pd.DataFrame(results)
    # Renombrar columnas para claridad
    df_results.rename(columns={'_id': 'estado', 'count': 'cantidad'}, inplace=True)
    display(df_results)

# %%
#11. Encontrar libros que tienen una descripción corta pero no una larga

# %%
if client:
    # Buscamos documentos donde shortDescription exista y longDescription sea null o no exista
    # $exists: True -> el campo existe
    # $exists: False -> el campo no existe
    # O podemos usar $in: [None] para buscar null (si es el caso)
    # O verificar si es null usando {"$type": 10} para null BSON type
    # Basado en el JSON, la ausencia del campo o su valor None son posibilidades
    # Usaremos $exists y un check para None/null

    # Consulta para documentos con shortDescription que existe Y longDescription que es null O no existe
    query = {
        "shortDescription": {"$exists": True, "$ne": None}, # Aseguramos que shortDescription existe y no es null
        "$or": [
            {"longDescription": None}, # longDescription es explicitamente null
            {"longDescription": {"$exists": False}} # longDescription no existe
        ]
    }
    
    print("Buscando libros con descripción corta pero sin descripción larga...")
    # Limitar resultados para mostrar
    results = list(collection.find(query, {'_id': 1, 'title': 1, 'shortDescription': 1, 'longDescription': 1}).limit(10))

    df_results = pd.DataFrame(results)
    print(f"Encontrados {len(results)} resultados (mostrando los primeros 10):")
    display(df_results)

# %%
#Vemos qué libros ha escrito "Robi Sen":

# %%
author = "Robi Sen"

# La consulta busca documentos donde el array 'authors' contenga el valor 'author'
query = {"authors": author}

print(f"Buscando libros escritos por '{author}'...")

# Ejecutamos la consulta y seleccionamos solo los campos _id, title, y authors para mostrar
results_cursor = collection.find(query, {'_id': 1, 'title': 1, 'authors': 1})

# Convertir el cursor a una lista y luego a DataFrame para visualización
results_list = list(results_cursor)
df_results = pd.DataFrame(results_list)

print(f"Encontrados {len(results_list)} resultados:")
display(df_results)
